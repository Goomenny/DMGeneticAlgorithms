# %%
import copy
import random as rn
import math
import cProfile
from matplotlib import pyplot as plt


import numpy as np
#rn.seed(7)
import GP
import problem

# %%
test = GP.Test(objective_function=problem.objective_function,variables=problem.variables)
stand, stady = test.start()
stand, stady = np.array(stand), np.array(stady)
# Out:
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5
# InitMaxDepth: 5

# %%
fig = plt.figure()
plt.plot(np.max(stand,2).mean(0),color="r")
plt.plot(np.max(stady,2).mean(0),color="b")
plt.plot(np.mean(stand,2).mean(0),color="r")
plt.plot(np.mean(stady,2).mean(0),color="b")
plt.plot(np.percentile(stand, axis=2,q=50).mean(0),color="black")
plt.plot(np.percentile(stady,axis=2,q=50).mean(0),color="g")
plt.plot(np.min(stand,2).mean(0),color="r")
plt.plot(np.min(stady,2).mean(0),color="b")
plt.show()

# %%
fig = plt.figure()
for line in np.max(stand,2):
    plt.plot(line,color="r")
for line in np.max(stady,2):
    plt.plot(line,color="b")

# plt.plot(np.percentile(stand, axis=2,q=50).mean(0),color="r")
# plt.plot(np.percentile(stady,axis=2,q=50).mean(0),color="b")
# plt.plot(np.min(stand,2).mean(0),color="r")
# plt.plot(np.min(stady,2).mean(0),color="b")
plt.grid()
plt.show()

# %%
fig = plt.figure()
plt.plot(np.max(stand,2).mean(0),color="r")
plt.plot(np.max(stady,2).mean(0),color="b")
plt.plot(np.mean(stand,2).mean(0),color="r")
plt.plot(np.mean(stady,2).mean(0),color="b")
plt.plot(np.percentile(stand, axis=2,q=50).mean(0),color="b")
plt.plot(np.percentile(stady,axis=2,q=50).mean(0),color="g")
plt.plot(np.min(stand,2).mean(0),color="r")
plt.plot(np.min(stady,2).mean(0),color="b")
plt.show()

# %%
fig = plt.figure()
for line in np.max(stand,2):
    plt.plot(line,color="r")
for line in np.max(stady,2):
    plt.plot(line,color="b")

# plt.plot(np.percentile(stand, axis=2,q=50).mean(0),color="r")
# plt.plot(np.percentile(stady,axis=2,q=50).mean(0),color="b")
# plt.plot(np.min(stand,2).mean(0),color="r")
# plt.plot(np.min(stady,2).mean(0),color="b")
plt.grid()
plt.show()
